# %%
# %pylab inline# Plotting sin and cosing functions the same way as ml-class/plotting lecutre
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
""" octave codet = [0:0.01:0.98];y1 = sin(2*pi*4*t);y2 = cos(2*pi*4*t);plot(t, y1);hold on;plot(t, y2, 'r');xlabel("time")ylabel("value")legend('sin', 'cos')title('my plot')print -dpng 'myplot.png'"""# python codet = np.linspace(0, 0.98, 99)y1 = np.sin(2*np.pi*4*t)plot(t,y1)y2 = cos(2*pi*4*t)plot(t,y2, 'r', label="hi")xlabel("time")ylabel("value")legend(['sin', 'cos'])title('my plot')savefig("first.png")
