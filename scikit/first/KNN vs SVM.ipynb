# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# Load
from sklearn.datasets import fetch_mldata
banana = fetch_mldata("banana-ida")
X = banana.data
y = banana.target
# Out:
# (5300, 2)

# %%
# Plot
from itertools import cycle
import pylab as pl
def plot_2d(X, y, labels):
    colors = cycle("rc")
    pl.figure()
    labels_ids = [-1, 1]
    for i, c, l in zip(labels_ids, colors, labels):
        pl.scatter(X[y == i, 0], X[y == i, 1], c=c, marker='+', label=l)
    
    pl.legend()

plot_2d(X, y, ["-1", "1"])

# %%
# 2 Unclassified Points
p1 = np.array([0, -1.5])
p2 = np.array([0.3, 0])

plot_2d(X, y, ["-1", "1"])

plot(point1[0], point1[1], 'bo')
plot(point1[0], point2[1], 'go')

# %%
# SVM
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(X, y)
print clf.predict(p1)
print clf.predict(p2)
# Out:
# [-1]
# [-1]

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)
print knn.predict(p1)
print knn.predict(p2)
# Out:
# [-1]
# [1]

# %%
# SVM Validation
validation = [i for i in range(X.shape[0]) if i % 4 == 0]
train = [i for i in range(X.shape[0]) if i % 4]

X_train, y_train = X[train, :], y[train]
X_validation, y_validation = X[validation, :], y[validation]
predictions = clf.predict(X_validation)
accuracy = float((predictions == y_validation).sum()) / len(validation)
print accuracy
# Out:
# 0.577358490566

# %%
# KNN Validation
validation = [i for i in range(X.shape[0]) if i % 4 == 0]
train = [i for i in range(X.shape[0]) if i % 4]

X_train, y_train = X[train, :], y[train]
X_validation, y_validation = X[validation, :], y[validation]
predictions = knn.predict(X_validation)
accuracy = float((predictions == y_validation).sum()) / len(validation)
print accuracy
# Out:
# 0.917735849057
