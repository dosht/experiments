# %%
# %pylab inline# Some idea to generate randome data to play with ml algorithms
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
rand = lambda mn, mx, num: [random.randint(mn, mx) + random.random() for i in range(num)]a = np.array([rand(1, 6, 100), rand(1, 9, 100)])b = np.array([rand(5, 10, 100), rand(1, 8, 100)])plot(a[0], a[1], 'ro', ms=3)plot(b[0], b[1], 'bo', ms=3)b1 = [9, 4]a1 = [1, 3]plot(b1[0], b1[1], '*',ms=10, mfc="m", mew=2, mec="m")plot(a1[0], a1[1], '*',ms=10, mfc="m", mew=2, mec="c")ab = [6,6]plot(ab[0], ab[1], '*',ms=10, mfc="r", mew=1, mec="b")axis([0, 10, 0, 10])a_labels = ['a' for i in a[0]]b_labels = ['b' for i in b[0]]
